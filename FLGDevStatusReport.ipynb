# %% [markdown]
# # FLG Development Status Report
# April 14, 2017

# %%
import pandas as pd

# %%
projects=pd.read_csv("http://leomercer.com/wp-content/uploads/2017/07/tabula-DSR-April-14-17.csv")

# %%
projects.head()
# Out:
#                     Project Name              Location Acres    Square Feet  \
# 0  Zoning Map Amendment (Rezone)                   NaN   NaN            NaN
# 1                  Juniper Point    JWP Blvd/Lone Tree   319  17,000‐85,000
# 2                 Canyon Del Rio  Butler Avenue/4th St   262            NaN
# 3                    Residential                   NaN   NaN            NaN
# 4             Arrowhead Duplexes   E. Arrowhead Avenue  0.45            NaN
#
#         Units/Lots/Rooms Project Description  Unnamed: 5 Downtown  \
# 0                                        NaN         NaN      NaN
# 1  1590 dwelling units Residential/Mixed Use         NaN      NaN
# 2  1390 dwelling units Residential/Mixed Use         NaN      NaN
# 3                                        NaN         NaN      NaN
# 4              21 dwelling units Residential         NaN      NaN
#
#                                               Status
# 0                                                NaN
# ...

# %%
projects.info
# Out:
# <bound method DataFrame.info of                           Project Name                            Location  \
# 0        Zoning Map Amendment (Rezone)                                 NaN
# 1                        Juniper Point                  JWP Blvd/Lone Tree
# 2                       Canyon Del Rio                Butler Avenue/4th St
# 3                          Residential                                 NaN
# 4                   Arrowhead Duplexes                 E. Arrowhead Avenue
# 5                      Arrowhead Lofts  E. Mountain View Ave/Arrowhead Ave
# 6                  Bungalows on Gemini                 N. Pine Cliff Drive
# 7      Forest Springs Townhomes Unit 2            N. Flowing Springs Trail
# 8               McMillan Mesa Tract IA                         Gemini Road
# 9           Miramonte at Beaver Street                    N. Beaver Street
# 10       Oakwood Village IV Apartments                      S. Yaqui Drive
# ...

# %%
projects.Status.value_counts().reset_index()
# Out:
#                                                 index  Status
# 0                                  Under Construction      35
# 1                                 Site Plan in review      14
# 2                                  Site Plan approved      14
# 3                  Temporary Certificate of Occupancy       4
# 4   Rezoning application in review; public hearing...       4
# 5                                  Under construction       2
# 6                                  Site Plan Approved       2
# 7   Site Plan approved; Civil and Building permit ...       2
# 8                      Annexation and Rezone approved       2
# 9                    Site Plan conditionally approved       2
# 10                          Preliminary plat approved       2
# 11                                             Status       1
